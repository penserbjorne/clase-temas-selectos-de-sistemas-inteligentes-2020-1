# %%
# Universidad Nacional Autónoma de México
# Facultad de Ingeniería
# Temas Selectos de Sistemas Inteligentes
# 2020-1
# Proyecto DNNs aplicadas a MNIST
# Aguilar Enriquez Paul Sebastian

# %%
import mnist_loader
# import network2
import network3
from network3 import Network, ConvPoolLayer, FullyConnectedLayer, SoftmaxLayer
# Out:
# Running with a CPU.  If this is not desired, then the modify network3.py to set
# the GPU flag to True.

# %%
# Cargamos MNIST
# Con network2
# training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Con network3
training_data, validation_data, test_data = network3.load_data_shared()

# %%
# Parametros
inputs = 784
layer1 = 30
outputs = 10
epochs = 40
mini_batch_size = 10
learning_rate = 0.1
regularization_parameter = 5.0

# Configuramos la red
# Con network2
# net = network3.Network([784, 30, 10])
# Con network3
net = Network([
    FullyConnectedLayer(n_in=inputs, n_out=layer1),
    SoftmaxLayer(n_in=layer1, n_out=outputs)], mini_batch_size)

# Entrenamos la red
# Con network2
# net.SGD(training_data, epochs, mini_batch_size, learning_rate, regularization_parameter, evaluation_data=validation_data, monitor_evaluation_accuracy = True)
# Con network3
net.SGD(training_data, epochs, mini_batch_size, learning_rate, validation_data, test_data, regularization_parameter)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 92.24%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 91.55%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 93.12%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 92.50%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 93.88%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.17%
# Training mini-batch number 15000
# Training mini-batch number 16000
# Training mini-batch number 17000
# Training mini-batch number 18000
# Training mini-batch number 19000
# Epoch 3: validation accuracy 94.07%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.52%
# Training mini-batch number 20000
# Training mini-batch number 21000
# Training mini-batch number 22000
# Training mini-batch number 23000
# Training mini-batch number 24000
# Epoch 4: validation accuracy 94.20%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.74%
# Training mini-batch number 25000
# Training mini-batch number 26000
# Training mini-batch number 27000
# Training mini-batch number 28000
# Training mini-batch number 29000
# Epoch 5: validation accuracy 94.38%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.92%
# Training mini-batch number 30000
# Training mini-batch number 31000
# Training mini-batch number 32000
# Training mini-batch number 33000
# Training mini-batch number 34000
# Epoch 6: validation accuracy 94.57%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.98%
# Training mini-batch number 35000
# Training mini-batch number 36000
# Training mini-batch number 37000
# Training mini-batch number 38000
# Training mini-batch number 39000
# Epoch 7: validation accuracy 94.66%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.04%
# Training mini-batch number 40000
# Training mini-batch number 41000
# Training mini-batch number 42000
# Training mini-batch number 43000
# Training mini-batch number 44000
# Epoch 8: validation accuracy 94.75%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.05%
# Training mini-batch number 45000
# Training mini-batch number 46000
# Training mini-batch number 47000
# Training mini-batch number 48000
# Training mini-batch number 49000
# Epoch 9: validation accuracy 94.73%
# Training mini-batch number 50000
# Training mini-batch number 51000
# Training mini-batch number 52000
# Training mini-batch number 53000
# Training mini-batch number 54000
# Epoch 10: validation accuracy 94.80%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.18%
# Training mini-batch number 55000
# Training mini-batch number 56000
# Training mini-batch number 57000
# Training mini-batch number 58000
# Training mini-batch number 59000
# Epoch 11: validation accuracy 94.81%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.26%
# Training mini-batch number 60000
# Training mini-batch number 61000
# Training mini-batch number 62000
# Training mini-batch number 63000
# Training mini-batch number 64000
# Epoch 12: validation accuracy 94.87%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.29%
# Training mini-batch number 65000
# Training mini-batch number 66000
# Training mini-batch number 67000
# Training mini-batch number 68000
# Training mini-batch number 69000
# Epoch 13: validation accuracy 94.84%
# Training mini-batch number 70000
# Training mini-batch number 71000
# Training mini-batch number 72000
# Training mini-batch number 73000
# Training mini-batch number 74000
# Epoch 14: validation accuracy 94.84%
# Training mini-batch number 75000
# Training mini-batch number 76000
# Training mini-batch number 77000
# Training mini-batch number 78000
# Training mini-batch number 79000
# Epoch 15: validation accuracy 94.84%
# Training mini-batch number 80000
# Training mini-batch number 81000
# Training mini-batch number 82000
# Training mini-batch number 83000
# Training mini-batch number 84000
# Epoch 16: validation accuracy 94.87%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.36%
# Training mini-batch number 85000
# Training mini-batch number 86000
# Training mini-batch number 87000
# Training mini-batch number 88000
# Training mini-batch number 89000
# Epoch 17: validation accuracy 94.86%
# Training mini-batch number 90000
# Training mini-batch number 91000
# Training mini-batch number 92000
# Training mini-batch number 93000
# Training mini-batch number 94000
# Epoch 18: validation accuracy 94.81%
# Training mini-batch number 95000
# Training mini-batch number 96000
# Training mini-batch number 97000
# Training mini-batch number 98000
# Training mini-batch number 99000
# Epoch 19: validation accuracy 94.87%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.41%
# Training mini-batch number 100000
# Training mini-batch number 101000
# Training mini-batch number 102000
# Training mini-batch number 103000
# Training mini-batch number 104000
# Epoch 20: validation accuracy 94.85%
# Training mini-batch number 105000
# Training mini-batch number 106000
# Training mini-batch number 107000
# Training mini-batch number 108000
# Training mini-batch number 109000
# Epoch 21: validation accuracy 94.90%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.43%
# Training mini-batch number 110000
# Training mini-batch number 111000
# Training mini-batch number 112000
# Training mini-batch number 113000
# Training mini-batch number 114000
# Epoch 22: validation accuracy 94.90%
# Training mini-batch number 115000
# Training mini-batch number 116000
# Training mini-batch number 117000
# Training mini-batch number 118000
# Training mini-batch number 119000
# Epoch 23: validation accuracy 94.89%
# Training mini-batch number 120000
# Training mini-batch number 121000
# Training mini-batch number 122000
# Training mini-batch number 123000
# Training mini-batch number 124000
# Epoch 24: validation accuracy 94.92%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.49%
# Training mini-batch number 125000
# Training mini-batch number 126000
# Training mini-batch number 127000
# Training mini-batch number 128000
# Training mini-batch number 129000
# Epoch 25: validation accuracy 94.92%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.47%
# Training mini-batch number 130000
# Training mini-batch number 131000
# Training mini-batch number 132000
# Training mini-batch number 133000
# Training mini-batch number 134000
# Epoch 26: validation accuracy 94.93%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.47%
# Training mini-batch number 135000
# Training mini-batch number 136000
# Training mini-batch number 137000
# Training mini-batch number 138000
# Training mini-batch number 139000
# Epoch 27: validation accuracy 94.94%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.50%
# Training mini-batch number 140000
# Training mini-batch number 141000
# Training mini-batch number 142000
# Training mini-batch number 143000
# Training mini-batch number 144000
# Epoch 28: validation accuracy 94.95%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.51%
# Training mini-batch number 145000
# Training mini-batch number 146000
# Training mini-batch number 147000
# Training mini-batch number 148000
# Training mini-batch number 149000
# Epoch 29: validation accuracy 94.93%
# Training mini-batch number 150000
# Training mini-batch number 151000
# Training mini-batch number 152000
# Training mini-batch number 153000
# Training mini-batch number 154000
# Epoch 30: validation accuracy 94.92%
# Training mini-batch number 155000
# Training mini-batch number 156000
# Training mini-batch number 157000
# Training mini-batch number 158000
# Training mini-batch number 159000
# Epoch 31: validation accuracy 94.96%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.52%
# Training mini-batch number 160000
# Training mini-batch number 161000
# Training mini-batch number 162000
# Training mini-batch number 163000
# Training mini-batch number 164000
# Epoch 32: validation accuracy 94.97%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.54%
# Training mini-batch number 165000
# Training mini-batch number 166000
# Training mini-batch number 167000
# Training mini-batch number 168000
# Training mini-batch number 169000
# Epoch 33: validation accuracy 94.95%
# Training mini-batch number 170000
# Training mini-batch number 171000
# Training mini-batch number 172000
# Training mini-batch number 173000
# Training mini-batch number 174000
# Epoch 34: validation accuracy 94.97%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.57%
# Training mini-batch number 175000
# Training mini-batch number 176000
# Training mini-batch number 177000
# Training mini-batch number 178000
# Training mini-batch number 179000
# Epoch 35: validation accuracy 94.96%
# Training mini-batch number 180000
# Training mini-batch number 181000
# Training mini-batch number 182000
# Training mini-batch number 183000
# Training mini-batch number 184000
# Epoch 36: validation accuracy 94.99%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.53%
# Training mini-batch number 185000
# Training mini-batch number 186000
# Training mini-batch number 187000
# Training mini-batch number 188000
# Training mini-batch number 189000
# Epoch 37: validation accuracy 94.99%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.54%
# Training mini-batch number 190000
# Training mini-batch number 191000
# Training mini-batch number 192000
# Training mini-batch number 193000
# Training mini-batch number 194000
# Epoch 38: validation accuracy 95.01%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.56%
# Training mini-batch number 195000
# Training mini-batch number 196000
# Training mini-batch number 197000
# Training mini-batch number 198000
# Training mini-batch number 199000
# Epoch 39: validation accuracy 95.02%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.54%
# Finished training network.
# Best validation accuracy of 95.02% obtained at iteration 199999
# Corresponding test accuracy of 94.54%

# %%
# Parametros
layer2 = 20

# Configuramos la red
net = Network([
    FullyConnectedLayer(n_in=inputs, n_out=layer1),
    FullyConnectedLayer(n_in=layer1, n_out=layer2),
    SoftmaxLayer(n_in=layer2, n_out=outputs)], mini_batch_size)

# Entrenamos la red
net.SGD(training_data, epochs, mini_batch_size, learning_rate, validation_data, test_data, regularization_parameter)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 90.81%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 89.61%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 92.47%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 91.83%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 93.27%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 92.79%
# Training mini-batch number 15000
# Training mini-batch number 16000
# Training mini-batch number 17000
# Training mini-batch number 18000
# Training mini-batch number 19000
# Epoch 3: validation accuracy 93.84%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.11%
# Training mini-batch number 20000
# Training mini-batch number 21000
# Training mini-batch number 22000
# Training mini-batch number 23000
# Training mini-batch number 24000
# Epoch 4: validation accuracy 94.15%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.36%
# Training mini-batch number 25000
# Training mini-batch number 26000
# Training mini-batch number 27000
# Training mini-batch number 28000
# Training mini-batch number 29000
# Epoch 5: validation accuracy 94.38%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.59%
# Training mini-batch number 30000
# Training mini-batch number 31000
# Training mini-batch number 32000
# Training mini-batch number 33000
# Training mini-batch number 34000
# Epoch 6: validation accuracy 94.50%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.76%
# Training mini-batch number 35000
# Training mini-batch number 36000
# Training mini-batch number 37000
# Training mini-batch number 38000
# Training mini-batch number 39000
# Epoch 7: validation accuracy 94.61%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.85%
# Training mini-batch number 40000
# Training mini-batch number 41000
# Training mini-batch number 42000
# Training mini-batch number 43000
# Training mini-batch number 44000
# Epoch 8: validation accuracy 94.70%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.01%
# Training mini-batch number 45000
# Training mini-batch number 46000
# Training mini-batch number 47000
# Training mini-batch number 48000
# Training mini-batch number 49000
# Epoch 9: validation accuracy 94.76%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.06%
# Training mini-batch number 50000
# Training mini-batch number 51000
# Training mini-batch number 52000
# Training mini-batch number 53000
# Training mini-batch number 54000
# Epoch 10: validation accuracy 94.81%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.17%
# Training mini-batch number 55000
# Training mini-batch number 56000
# Training mini-batch number 57000
# Training mini-batch number 58000
# Training mini-batch number 59000
# Epoch 11: validation accuracy 94.83%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.27%
# Training mini-batch number 60000
# Training mini-batch number 61000
# Training mini-batch number 62000
# Training mini-batch number 63000
# Training mini-batch number 64000
# Epoch 12: validation accuracy 94.89%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.31%
# Training mini-batch number 65000
# Training mini-batch number 66000
# Training mini-batch number 67000
# Training mini-batch number 68000
# Training mini-batch number 69000
# Epoch 13: validation accuracy 94.95%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.35%
# Training mini-batch number 70000
# Training mini-batch number 71000
# Training mini-batch number 72000
# Training mini-batch number 73000
# Training mini-batch number 74000
# Epoch 14: validation accuracy 95.02%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.40%
# Training mini-batch number 75000
# Training mini-batch number 76000
# Training mini-batch number 77000
# Training mini-batch number 78000
# Training mini-batch number 79000
# Epoch 15: validation accuracy 95.01%
# Training mini-batch number 80000
# Training mini-batch number 81000
# Training mini-batch number 82000
# Training mini-batch number 83000
# Training mini-batch number 84000
# Epoch 16: validation accuracy 94.98%
# Training mini-batch number 85000
# Training mini-batch number 86000
# Training mini-batch number 87000
# Training mini-batch number 88000
# Training mini-batch number 89000
# Epoch 17: validation accuracy 95.02%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.51%
# Training mini-batch number 90000
# Training mini-batch number 91000
# Training mini-batch number 92000
# Training mini-batch number 93000
# Training mini-batch number 94000
# Epoch 18: validation accuracy 94.96%
# Training mini-batch number 95000
# Training mini-batch number 96000
# Training mini-batch number 97000
# Training mini-batch number 98000
# Training mini-batch number 99000
# Epoch 19: validation accuracy 94.95%
# Training mini-batch number 100000
# Training mini-batch number 101000
# Training mini-batch number 102000
# Training mini-batch number 103000
# Training mini-batch number 104000
# Epoch 20: validation accuracy 94.95%
# Training mini-batch number 105000
# Training mini-batch number 106000
# Training mini-batch number 107000
# Training mini-batch number 108000
# Training mini-batch number 109000
# Epoch 21: validation accuracy 94.94%
# Training mini-batch number 110000
# Training mini-batch number 111000
# Training mini-batch number 112000
# Training mini-batch number 113000
# Training mini-batch number 114000
# Epoch 22: validation accuracy 94.92%
# Training mini-batch number 115000
# Training mini-batch number 116000
# Training mini-batch number 117000
# Training mini-batch number 118000
# Training mini-batch number 119000
# Epoch 23: validation accuracy 94.92%
# Training mini-batch number 120000
# Training mini-batch number 121000
# Training mini-batch number 122000
# Training mini-batch number 123000
# Training mini-batch number 124000
# Epoch 24: validation accuracy 94.96%
# Training mini-batch number 125000
# Training mini-batch number 126000
# Training mini-batch number 127000
# Training mini-batch number 128000
# Training mini-batch number 129000
# Epoch 25: validation accuracy 94.98%
# Training mini-batch number 130000
# Training mini-batch number 131000
# Training mini-batch number 132000
# Training mini-batch number 133000
# Training mini-batch number 134000
# Epoch 26: validation accuracy 95.00%
# Training mini-batch number 135000
# Training mini-batch number 136000
# Training mini-batch number 137000
# Training mini-batch number 138000
# Training mini-batch number 139000
# Epoch 27: validation accuracy 95.01%
# Training mini-batch number 140000
# Training mini-batch number 141000
# Training mini-batch number 142000
# Training mini-batch number 143000
# Training mini-batch number 144000
# Epoch 28: validation accuracy 95.01%
# Training mini-batch number 145000
# Training mini-batch number 146000
# Training mini-batch number 147000
# Training mini-batch number 148000
# Training mini-batch number 149000
# Epoch 29: validation accuracy 94.99%
# Training mini-batch number 150000
# Training mini-batch number 151000
# Training mini-batch number 152000
# Training mini-batch number 153000
# Training mini-batch number 154000
# Epoch 30: validation accuracy 94.99%
# Training mini-batch number 155000
# Training mini-batch number 156000
# Training mini-batch number 157000
# Training mini-batch number 158000
# Training mini-batch number 159000
# Epoch 31: validation accuracy 95.01%
# Training mini-batch number 160000
# Training mini-batch number 161000
# Training mini-batch number 162000
# Training mini-batch number 163000
# Training mini-batch number 164000
# Epoch 32: validation accuracy 95.03%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.57%
# Training mini-batch number 165000
# Training mini-batch number 166000
# Training mini-batch number 167000
# Training mini-batch number 168000
# Training mini-batch number 169000
# Epoch 33: validation accuracy 95.01%
# Training mini-batch number 170000
# Training mini-batch number 171000
# Training mini-batch number 172000
# Training mini-batch number 173000
# Training mini-batch number 174000
# Epoch 34: validation accuracy 95.01%
# Training mini-batch number 175000
# Training mini-batch number 176000
# Training mini-batch number 177000
# Training mini-batch number 178000
# Training mini-batch number 179000
# Epoch 35: validation accuracy 95.01%
# Training mini-batch number 180000
# Training mini-batch number 181000
# Training mini-batch number 182000
# Training mini-batch number 183000
# Training mini-batch number 184000
# Epoch 36: validation accuracy 95.02%
# Training mini-batch number 185000
# Training mini-batch number 186000
# Training mini-batch number 187000
# Training mini-batch number 188000
# Training mini-batch number 189000
# Epoch 37: validation accuracy 95.01%
# Training mini-batch number 190000
# Training mini-batch number 191000
# Training mini-batch number 192000
# Training mini-batch number 193000
# Training mini-batch number 194000
# Epoch 38: validation accuracy 95.01%
# Training mini-batch number 195000
# Training mini-batch number 196000
# Training mini-batch number 197000
# Training mini-batch number 198000
# Training mini-batch number 199000
# Epoch 39: validation accuracy 95.01%
# Finished training network.
# Best validation accuracy of 95.03% obtained at iteration 164999
# Corresponding test accuracy of 94.57%

# %%
# Parametros
layer3 = 20

# Configuramos la red
net = Network([
    FullyConnectedLayer(n_in=inputs, n_out=layer1),
    FullyConnectedLayer(n_in=layer1, n_out=layer2),
    FullyConnectedLayer(n_in=layer3, n_out=layer3),
    SoftmaxLayer(n_in=layer3, n_out=outputs)], mini_batch_size)

# Entrenamos la red
net.SGD(training_data, epochs, mini_batch_size, learning_rate, validation_data, test_data, regularization_parameter)
# Out:
# Training mini-batch number 0
# Training mini-batch number 1000
# Training mini-batch number 2000
# Training mini-batch number 3000
# Training mini-batch number 4000
# Epoch 0: validation accuracy 77.76%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 77.27%
# Training mini-batch number 5000
# Training mini-batch number 6000
# Training mini-batch number 7000
# Training mini-batch number 8000
# Training mini-batch number 9000
# Epoch 1: validation accuracy 89.88%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 89.23%
# Training mini-batch number 10000
# Training mini-batch number 11000
# Training mini-batch number 12000
# Training mini-batch number 13000
# Training mini-batch number 14000
# Epoch 2: validation accuracy 91.64%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 91.18%
# Training mini-batch number 15000
# Training mini-batch number 16000
# Training mini-batch number 17000
# Training mini-batch number 18000
# Training mini-batch number 19000
# Epoch 3: validation accuracy 92.56%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 91.96%
# Training mini-batch number 20000
# Training mini-batch number 21000
# Training mini-batch number 22000
# Training mini-batch number 23000
# Training mini-batch number 24000
# Epoch 4: validation accuracy 93.30%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 92.58%
# Training mini-batch number 25000
# Training mini-batch number 26000
# Training mini-batch number 27000
# Training mini-batch number 28000
# Training mini-batch number 29000
# Epoch 5: validation accuracy 93.86%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.07%
# Training mini-batch number 30000
# Training mini-batch number 31000
# Training mini-batch number 32000
# Training mini-batch number 33000
# Training mini-batch number 34000
# Epoch 6: validation accuracy 94.23%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.51%
# Training mini-batch number 35000
# Training mini-batch number 36000
# Training mini-batch number 37000
# Training mini-batch number 38000
# Training mini-batch number 39000
# Epoch 7: validation accuracy 94.52%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 93.83%
# Training mini-batch number 40000
# Training mini-batch number 41000
# Training mini-batch number 42000
# Training mini-batch number 43000
# Training mini-batch number 44000
# Epoch 8: validation accuracy 94.63%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.01%
# Training mini-batch number 45000
# Training mini-batch number 46000
# Training mini-batch number 47000
# Training mini-batch number 48000
# Training mini-batch number 49000
# Epoch 9: validation accuracy 94.75%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.07%
# Training mini-batch number 50000
# Training mini-batch number 51000
# Training mini-batch number 52000
# Training mini-batch number 53000
# Training mini-batch number 54000
# Epoch 10: validation accuracy 94.74%
# Training mini-batch number 55000
# Training mini-batch number 56000
# Training mini-batch number 57000
# Training mini-batch number 58000
# Training mini-batch number 59000
# Epoch 11: validation accuracy 94.79%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.20%
# Training mini-batch number 60000
# Training mini-batch number 61000
# Training mini-batch number 62000
# Training mini-batch number 63000
# Training mini-batch number 64000
# Epoch 12: validation accuracy 94.79%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.18%
# Training mini-batch number 65000
# Training mini-batch number 66000
# Training mini-batch number 67000
# Training mini-batch number 68000
# Training mini-batch number 69000
# Epoch 13: validation accuracy 94.83%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.29%
# Training mini-batch number 70000
# Training mini-batch number 71000
# Training mini-batch number 72000
# Training mini-batch number 73000
# Training mini-batch number 74000
# Epoch 14: validation accuracy 94.85%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.35%
# Training mini-batch number 75000
# Training mini-batch number 76000
# Training mini-batch number 77000
# Training mini-batch number 78000
# Training mini-batch number 79000
# Epoch 15: validation accuracy 94.86%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.42%
# Training mini-batch number 80000
# Training mini-batch number 81000
# Training mini-batch number 82000
# Training mini-batch number 83000
# Training mini-batch number 84000
# Epoch 16: validation accuracy 94.86%
# Training mini-batch number 85000
# Training mini-batch number 86000
# Training mini-batch number 87000
# Training mini-batch number 88000
# Training mini-batch number 89000
# Epoch 17: validation accuracy 94.96%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.41%
# Training mini-batch number 90000
# Training mini-batch number 91000
# Training mini-batch number 92000
# Training mini-batch number 93000
# Training mini-batch number 94000
# Epoch 18: validation accuracy 94.98%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.42%
# Training mini-batch number 95000
# Training mini-batch number 96000
# Training mini-batch number 97000
# Training mini-batch number 98000
# Training mini-batch number 99000
# Epoch 19: validation accuracy 94.99%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.50%
# Training mini-batch number 100000
# Training mini-batch number 101000
# Training mini-batch number 102000
# Training mini-batch number 103000
# Training mini-batch number 104000
# Epoch 20: validation accuracy 95.01%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.52%
# Training mini-batch number 105000
# Training mini-batch number 106000
# Training mini-batch number 107000
# Training mini-batch number 108000
# Training mini-batch number 109000
# Epoch 21: validation accuracy 95.05%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.56%
# Training mini-batch number 110000
# Training mini-batch number 111000
# Training mini-batch number 112000
# Training mini-batch number 113000
# Training mini-batch number 114000
# Epoch 22: validation accuracy 95.03%
# Training mini-batch number 115000
# Training mini-batch number 116000
# Training mini-batch number 117000
# Training mini-batch number 118000
# Training mini-batch number 119000
# Epoch 23: validation accuracy 95.06%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.61%
# Training mini-batch number 120000
# Training mini-batch number 121000
# Training mini-batch number 122000
# Training mini-batch number 123000
# Training mini-batch number 124000
# Epoch 24: validation accuracy 95.07%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.65%
# Training mini-batch number 125000
# Training mini-batch number 126000
# Training mini-batch number 127000
# Training mini-batch number 128000
# Training mini-batch number 129000
# Epoch 25: validation accuracy 94.99%
# Training mini-batch number 130000
# Training mini-batch number 131000
# Training mini-batch number 132000
# Training mini-batch number 133000
# Training mini-batch number 134000
# Epoch 26: validation accuracy 95.07%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.72%
# Training mini-batch number 135000
# Training mini-batch number 136000
# Training mini-batch number 137000
# Training mini-batch number 138000
# Training mini-batch number 139000
# Epoch 27: validation accuracy 95.11%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.69%
# Training mini-batch number 140000
# Training mini-batch number 141000
# Training mini-batch number 142000
# Training mini-batch number 143000
# Training mini-batch number 144000
# Epoch 28: validation accuracy 95.10%
# Training mini-batch number 145000
# Training mini-batch number 146000
# Training mini-batch number 147000
# Training mini-batch number 148000
# Training mini-batch number 149000
# Epoch 29: validation accuracy 95.15%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.74%
# Training mini-batch number 150000
# Training mini-batch number 151000
# Training mini-batch number 152000
# Training mini-batch number 153000
# Training mini-batch number 154000
# Epoch 30: validation accuracy 95.12%
# Training mini-batch number 155000
# Training mini-batch number 156000
# Training mini-batch number 157000
# Training mini-batch number 158000
# Training mini-batch number 159000
# Epoch 31: validation accuracy 95.11%
# Training mini-batch number 160000
# Training mini-batch number 161000
# Training mini-batch number 162000
# Training mini-batch number 163000
# Training mini-batch number 164000
# Epoch 32: validation accuracy 95.11%
# Training mini-batch number 165000
# Training mini-batch number 166000
# Training mini-batch number 167000
# Training mini-batch number 168000
# Training mini-batch number 169000
# Epoch 33: validation accuracy 95.11%
# Training mini-batch number 170000
# Training mini-batch number 171000
# Training mini-batch number 172000
# Training mini-batch number 173000
# Training mini-batch number 174000
# Epoch 34: validation accuracy 95.11%
# Training mini-batch number 175000
# Training mini-batch number 176000
# Training mini-batch number 177000
# Training mini-batch number 178000
# Training mini-batch number 179000
# Epoch 35: validation accuracy 95.11%
# Training mini-batch number 180000
# Training mini-batch number 181000
# Training mini-batch number 182000
# Training mini-batch number 183000
# Training mini-batch number 184000
# Epoch 36: validation accuracy 95.13%
# Training mini-batch number 185000
# Training mini-batch number 186000
# Training mini-batch number 187000
# Training mini-batch number 188000
# Training mini-batch number 189000
# Epoch 37: validation accuracy 95.13%
# Training mini-batch number 190000
# Training mini-batch number 191000
# Training mini-batch number 192000
# Training mini-batch number 193000
# Training mini-batch number 194000
# Epoch 38: validation accuracy 95.11%
# Training mini-batch number 195000
# Training mini-batch number 196000
# Training mini-batch number 197000
# Training mini-batch number 198000
# Training mini-batch number 199000
# Epoch 39: validation accuracy 95.16%
# This is the best validation accuracy to date.
# The corresponding test accuracy is 94.84%
# Finished training network.
# Best validation accuracy of 95.16% obtained at iteration 199999
# Corresponding test accuracy of 94.84%
